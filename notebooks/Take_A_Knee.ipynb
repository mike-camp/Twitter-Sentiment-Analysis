# %%
import requests
from src.apikeys import TWITTER, MONGO
import tweepy
from tweepy.auth import OAuthHandler
from tweepy.streaming import StreamListener
from tweepy import Stream

# %%
auth = OAuthHandler(TWITTER.CONSUMER_KEY,TWITTER.CONSUMER_SECRET)
auth.set_access_token(TWITTER.ACCESS_TOKEN, TWITTER.ACCESS_SECRET)
from pymongo import MongoClient
client = MongoClient('mongodb://{}:{}@localhost:27017'.format(MONGO.USER,MONGO.PASSWORD))
# Access/Initiate Database
db = client['twitter_database']
# Access/Initiate Table
tab = db['knee']
class MyStreamListener(StreamListener):
    def on_status(self, status):
        if not hasattr(self, 'i'):
            self.i=0
        tab.insert_one(status._json)
        self.i+=1
        if self.i%1000==0:
            print(status.text)
        
    def on_error(self, status_code):
        print(status_code)
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False

# %%
twitterStream = Stream(auth, MyStreamListener())
twitterStream.filter(track=['Takeaknee','takeaknee'])
# Out:
# RT @kasalei_: Together we are, together we will.. #TakeaKnee JCSU Volleyball. https://t.co/D4CIC6IN0i
# RT @H_Town_74: HANDS DOWN.@ACLU has delivered the #TakeAKnee TWEET OF THE DAY! It's so good you MUST DONATE!!#TheResistance #CNN…
# @CNN #NFLBoycott #StandUp #StandForTheFlag
#
# Do not #TakeAKnee !  #disrespect
# Friend of mine just sent this from tonight's Raiders vs. Redskins game. #TakeAKnee https://t.co/uP5W3l6PT0
# RT @brennanmgilmore: My grandpa is a 97 year-old WWII vet &amp; Missouri farmer who wanted to join w/ those who #TakeaKnee: "those kids have…
# RT @iJesseWilliams: We’re not on the plantation anymore Chump. There will be no “buck breaking” out here. Fingers on the hand form a fist.…
# RT @itsgabrielleu: Exactly https://t.co/oEKy41fyyT
# RT @brennanmgilmore: My grandpa is a 97 year-old WWII vet &amp; Missouri farmer who wanted to join w/ those who #TakeaKnee: "those kids have…
# RT @MichellePiper18: While Everyone Wonders Who Will #TakeTheKnee We Remember One American Hero Who Never Will 🇺🇸🇺🇸🇺🇸
#
# https://t.co/piwIvQH…
# RT @KeriHilson: ✊🏾 #TakeAKnee #ImWithKap https://t.co/AZMmIXOqEc
# RT @TheUndefeated: Racism. Police brutality. This is what the NFL protests were about from the start. Not about disrespecting the flag…
# RT @HireMeImFunny: NFL players aren't protesting the anthem, they're protesting police brutality. That's like saying hunger strikes are aga…
# RT @RVAwonk: #Kaepernick started kneeling in protest during Obama's presidency. This wasn't abt Trump until Trump tried to make…
# RT @cmclymer: FYI for media: USWNT's Megan Rapinoe was the first white professional athlete to take a knee w/ Kaepernick, over a…
# RT @NancySinatra: We've got you, Ed. ❤️🇺🇸 https://t.co/51AyiztDR7
# RT @KamVTV: #TakeAKnee but get threatened with a fine for wanting to put #NeverForget on your cleats to memorialize those kille…
# RT @KamVTV: So to protest income equality will you refuse your paycheck?
#
# #TakeAKnee  #RiseUp #WNBAfinals #MAGA https://t.co/3d0nMQs6tF
# RT @SafetyPinDaily: Stevie Wonder joins #takeaknee protest against Trump's attack on NFL players  | Via @guardian
# https://t.co/b9qTjg4vLe
# RT @tonyposnanski: Colin Kaepernick- Son of a Bitch
#
# Joe Arpaio- Pardoned
#
# Just in case you ever questioned that "White Supremacist" comme…
# RT @daveweigel: People who mocked “safe spaces” five minutes ago now busily filling their diapers over Kaepernick’s sock choice https://t.c…
# RT @KNP2BP: Saddened when I see #NFL millionaires #TakeAKnee
#
# Think of #PatTIllman who gave up a glamorous NFL life to serve US https://t.…
# RT @brennanmgilmore: My grandpa is a 97 year-old WWII vet &amp; Missouri farmer who wanted to join w/ those who #TakeaKnee: "those kids have…

# RT @brennanmgilmore: My grandpa is a 97 year-old WWII vet &amp; Missouri farmer who wanted to join w/ those who #TakeaKnee: "those kids have…
# RT @brennanmgilmore: My grandpa is a 97 year-old WWII vet &amp; Missouri farmer who wanted to join w/ those who #TakeaKnee: "those kids have…
# RT @larryelder: Sooner or later, the @NFL and @NBA players are going to learn what owner Michael Jordan knows--republicans buy shoes, too.…
# RT @mikandynothem: Tebow wore John 3:16 during
# a game, 93 million looked it up. Now players are disrespecting our flag.
# Compare and c…
# RT @brennanmgilmore: My grandpa is a 97 year-old WWII vet &amp; Missouri farmer who wanted to join w/ those who #TakeaKnee: "those kids have…
# RT @PearlJam: #TakeAKnee https://t.co/rSU8zT7mlI
# RT @TheOnlyEdAsner: I am taking a knee on Sunday.  I might need someone to help me up.  #TakeAKnee
# RT @W_C_Patriot: My bestie and I are doing #Oktoberfest🍻 instead of  watching NFL tonight.
# RT and tell us what you are doing.…
# RT @PearlJam: #TakeAKnee https://t.co/rSU8zT7mlI
# RT @WayneDupreeShow: 🤣 #TakeAKnee Huh?
#
# The @NAACP has been taken over by socialist, communist &amp; racists. It will never be what our fath…
# RT @BreeNewsome: Don't allow racists to reframe #TakeAKnee as being a debate about anthem &amp; flag. It's a protest of police brutality &amp; raci…
# RT @freeSPIRIT_5678: Proudest &amp; scariest moment as a yellow-jacket happened at the same time. Thank you @Kaepernick7 for inspiring to…
# RT @yourrightscamp: Travis Kelce took a knee today during the National Anthem ✊🏾✊🏼✊🏽✊🏿✊🏻 #imwithkap #takeaknee https://t.co/9gQopcK1Yy
# RT @Dave_Hile: I'm a Vet and I'm taking a knee. I didn't serve and defend our Country so a white supremacist could tear it apart. #TakeAKnee
# RT @joncoopertweets: #BREAKING: @theDemCoalition is filing a complaint on Trump today w/ Office of Gov't Ethics for calling on NFL to fire…
# RT @SmallBiz4Trump: Trump won w voters like Rose. Now #RadicalLeft DEMS supporting #TakeAKnee antiflag protest. Sure that's a winning m…
# RT @peterdaou: 4. "Disrespecting our flag" is standing down as a hostile foreign power interferes in our free elections. https://t.co/KUfjO…
# RT @TheUndefeated: Racism. Police brutality. This is what the NFL protests were about from the start. Not about disrespecting the flag…
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /home/michael/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /home/michael/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /home/michael/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ef8c97f56fc4> in <module>()
#       1 twitterStream = Stream(auth, MyStreamListener())
# ----> 2 twitterStream.filter(track=['Takeaknee','takeaknee'])
#
# /home/michael/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /home/michael/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# /home/michael/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# /home/michael/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# /home/michael/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# /home/michael/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# /home/michael/anaconda3/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# /home/michael/anaconda3/lib/python3.6/http/client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# /home/michael/anaconda3/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# /home/michael/anaconda3/lib/python3.6/http/client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# /home/michael/anaconda3/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# /home/michael/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /home/michael/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     287                 raise
#     288         except OpenSSL.SSL.WantReadError:
# --> 289             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     290             if not rd:
#     291                 raise timeout('The read operation timed out')
#
# /home/michael/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/util/wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# /home/michael/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/util/wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# /home/michael/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/util/selectors.py in select(self, timeout)
#     436             fd_events = _syscall_wrapper(self._epoll.poll, True,
#     437                                          timeout=timeout,
# --> 438                                          maxevents=max_events)
#     439             for fd, event_mask in fd_events:
#     440                 events = 0
#
# /home/michael/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/util/selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# KeyboardInterrupt:
